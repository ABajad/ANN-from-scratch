# %% [markdown]
# <a href="https://colab.research.google.com/github/ABajad/ANN-from-scratch/blob/master/Adding_Layers.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Layer Till Now

# %%
import numpy as np

inputs = [[1, 2, 3, 2.5], [2., 5., -1., 2], [-1.5, 2.7, 3.3, -0.8]]
weights = [ [0.2, 0.8, -0.5, 1],
            [0.5, -0.91, 0.26, -0.5],
            [-0.26, -0.27, 0.17, 0.87]  ]
biases = [2, 3, 0.5]

weights2 = [  [0.1, -0.14, 0.5],
              [-0.5, 0.12, -0.33],

              [-0.44, 0.73, -0.13]  ]
biases2 = [-1, 2, -0.5]

layer1_outputs = np.dot(inputs, np.array(weights).T) + np.array(biases)
layer2_outputs = np.dot(layer1_outputs, np.array(weights2).T) + np.array(biases2)
print(layer2_outputs)
# Out:
# [[ 0.5031  -1.04185 -2.03875]
#  [ 0.2434  -2.7332  -5.7633 ]
#  [-0.99314  1.41254 -0.35655]]

# %% [markdown]
# #Genrating Data

# %%
import numpy as np
np.random.seed(0)
#https://cs231n.github.io/neural-networks-case-study/
def create_data(points, classes):
  X = np.zeros((points*classes, 2))
  y = np.zeros(points*classes, dtype='uint8')
  for class_number in range(classes):
    ix = range(points*class_number, points*(class_number+1))
    r = np.linspace(0.0, 1, points) # radius
    t = np.linspace(class_number*4, (class_number+1)*4, points) + np.random.randn(points)*0.2
    X[ix] = np.c_[r*np.sin(t*2.5), r*np.cos(t*2.5)]
    y[ix] = class_number
  return X, y

# %%
import matplotlib.pyplot as plt
X, y = create_data(100, 3)
plt.scatter(X[:,0], X[:,1], c=y, cmap="brg")
plt.show()

# %% [markdown]
# # Dense Layer

# %%
class Layer_Dense:

  def __init__(self, inputs, neurons):
    #initialize weights and biases
    self.weights = 0.01*np.random.randn(inputs, neurons)
    self.biases = np.zeros((1,neurons)) 

  def forward(self, inputs):
    #Calculate output values
    self.output = np.dot(inputs, self.weights) + self.biases

# %%
X, y = create_data(100,3)

dense1 = Layer_Dense(2,3)

dense1.forward(X)

print(dense1.output[:5])
# Out:
# [[ 0.00000000e+00  0.00000000e+00  0.00000000e+00]
#  [-2.66863470e-05 -1.02978810e-04  1.86669859e-04]
#  [ 1.15864559e-04 -1.28976083e-04  3.35053393e-04]
#  [-1.28849912e-04 -3.20290324e-04  5.49492867e-04]
#  [ 2.47419625e-04 -2.47545583e-04  6.60056055e-04]]

# %% [markdown]
# #Full Code Now

# %%
import numpy as np
np.random.seed(0)

def create_data(points, classes):

  X = np.zeros((points*classes, 2))
  y = np.zeros(points*classes, dtype='uint8')
  for class_number in range(classes):
    ix = range(points*class_number, points*(class_number+1))
    r = np.linspace(0.0, 1, points)
    t = np.linspace(class_number*4, (class_number+1)*4, points) + np.random.randn(points)*0.05
    X[ix] = np.c_[r*np.sin(t*2.5), r*np.cos(t*2.5)]
    y[ix] = class_number
  return X, y
class Layer_Dense:
  def __init__(self, inputs, neurons):
    self.weights = 0.01 * np.random.randn(inputs, neurons)
    self.biases = np.zeros((1, neurons))
  def forward(self, inputs):
    self.output = np.dot(inputs, self.weights) + self.biases
# Create dataset
X, y = create_data(100, 3)
# Create Dense layer with 2 input features and 3 output values
dense1 = Layer_Dense(2, 3) # first dense layer, 2 inputs (each sample has 2 features), 3 outputs
# Make a forward pass of the training data through this layer
dense1.forward(X)
# Let's see output for first few samples:
print(dense1.output[:5])
# Out:
# [[ 0.00000000e+00  0.00000000e+00  0.00000000e+00]
#  [-8.77788516e-05  9.17448014e-05 -4.78034121e-05]
#  [-2.14364799e-04  2.34361157e-04 -9.58292044e-05]
#  [-3.90062984e-04  4.45243326e-04 -1.36256561e-04]
#  [-5.35031035e-04  6.15104009e-04 -1.78004284e-04]]
